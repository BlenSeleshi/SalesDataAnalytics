# %% [markdown]
# ### Importing the Necessary Packages

# %%
import pandas as pd
import sys, os
import warnings
warnings.filterwarnings('ignore') 
import seaborn as sns

# %%
sys.path.append(os.path.abspath('../scripts'))

# %%
import salesAnalysis as sa

# %% [markdown]
# ### Loading the Dataset

# %%
train_store = sa.load_data(r'C:\Users\Blen\OneDrive\Desktop\10Academy\SalesDataAnalytics\Data\train_store.csv')
# Out:
# 2024-09-20 22:21:09,296 - INFO - Loading the Dataset datastes from file...

# %%
   # Ensure that 'Date' column is in datetime format
train_store['Date'] = pd.to_datetime(train_store['Date'], errors='coerce')  # This forces invalid dates to NaT (Not a Time)

# %%
train_store.head()
# Out:
#    Store  DayOfWeek       Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5 2015-07-31   5263        555     1      1            0
# 1      2          5 2015-07-31   6064        625     1      1            0
# 2      3          5 2015-07-31   8314        821     1      1            0
# 3      4          5 2015-07-31  13995       1498     1      1            0
# 4      5          5 2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0              1         c          a               1270.0
# 1              1         a          a                570.0
# 2              1         a          a              14130.0
# 3              1         c          c                620.0
# 4              1         a          a              29910.0
#
#    CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                        9.0                    2008.0       0
# ...

# %% [markdown]
# ### 1.Promotion Distribution:

# %% [markdown]
# #### 1.1. Promotion Distribution on Training Set

# %%
sa.promo_distribution(train_store)
# Out:
# 2024-09-20 19:51:55,132 - INFO - Calculating and plotting the distribution of promotion....
# Promotion Distribution in Training Set:
# Promo
# 0    61.848548
# 1    38.151452
# Name: proportion, dtype: float64
# 2024-09-20 19:51:55,883 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-09-20 19:51:56,279 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.

# %% [markdown]
# #### 1.2. Promotion Distribution on Test Set

# %%
test_df = sa.load_data(r'C:\Users\Blen\OneDrive\Desktop\10Academy\SalesDataAnalytics\Data\test.csv')
# Out:
# 2024-09-20 19:51:56,609 - INFO - Loading the Dataset datastes from file...

# %%
sa.promo_distribution(test_df)
# Out:
# 2024-09-20 19:51:56,660 - INFO - Calculating and plotting the distribution of promotion....
# 2024-09-20 19:51:56,741 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-09-20 19:51:56,765 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# Promotion Distribution in Training Set:
# Promo
# 0    60.416667
# 1    39.583333
# Name: proportion, dtype: float64

# %% [markdown]
# ### 2. Sales Behaviour Around Holidays

# %%
sa.analyze_holiday_effects(train_store)
# Out:
# 2024-09-20 19:51:56,862 - INFO - Plotting the Sales behaviour round the holidays...

# %% [markdown]
# ### 3. Analyzing seasonal behavior (Christmas, Easter, etc.)

# %%
sa.seasonal_sales_behavior(train_store)
# Out:
# 2024-09-20 19:52:09,516 - INFO - Plotting the Seasonal Sales Behaviour...
# 2024-09-20 19:52:09,626 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-09-20 19:52:09,643 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.

# %% [markdown]
# ### 4. Day of the Week Sales

# %%
sa.plot_day_of_week_sales(train_store)
# Out:
# 2024-09-20 19:55:34,562 - INFO - Plotting average sales by day of week...

# %% [markdown]
# ### 5. Statistics of sales on holidays and day of the week

# %%
sa.print_statistics(train_store)
# Out:
# 2024-09-20 19:56:59,741 - INFO - Printing summary statistics...
#               count         mean          std  min      25%     50%     75%  \
# DayOfWeek
# 1          144730.0  7809.044510  4016.526273  0.0  5235.00  7310.0  9972.0
# 2          145664.0  7005.244467  3142.039607  0.0  4904.00  6463.0  8491.0
# 3          145665.0  6555.884138  2944.377501  0.0  4718.00  6133.0  7926.0
# 4          145845.0  6247.575913  3209.806360  0.0  4536.00  6020.0  7792.0
# 5          145845.0  6723.274305  3101.006008  0.0  4975.00  6434.0  8206.0
# 6          144730.0  5847.562599  2873.985615  0.0  3899.25  5410.0  7220.0
# 7          144730.0   204.183189  1613.243517  0.0     0.00     0.0     0.0
#
#                max
# DayOfWeek
# 1          41551.0
# 2          34692.0
# 3          33151.0
# 4          38367.0
# 5          38722.0
# 6          31683.0
# 7          37376.0
#
# Holiday vs Non-Holiday Sales:
# ...

# %% [markdown]
# ### 6. Correlation between sales and number of customers

# %%
sa.sales_customers_correlation(train_store)
# Out:
# 2024-09-20 19:59:04,478 - INFO - Analyzing the correlation between sales and customers....
# Correlation between Sales and Customers: 0.89

# %% [markdown]
# ### 7. Promo effect on sales and customers

# %%
sa.promo_effect_on_sales(train_store)
# Out:
# 2024-09-20 19:59:45,798 - INFO - Plotting the effect of promotion on sales....
# 2024-09-20 19:59:45,898 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-09-20 19:59:45,898 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-09-20 19:59:45,932 - INFO - Plotting the effect of promotion on customers...
# 2024-09-20 19:59:45,941 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# ...

# %% [markdown]
# #### 7.1 Effect of Promotion 1 and 2 on sales through out the weekdays

# %%
# sale per customer trends
sns.catplot(data = train_store, x = 'DayOfWeek', y = "Sales", 
               col = 'Promo', 
               row = 'Promo2',
               hue = 'Promo2',
               palette = 'RdPu',
               kind='point')
# Out:
# 2024-09-20 22:21:20,791 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-09-20 22:21:21,420 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.

# %% [markdown]
# #### 7.1 Effect of Promotion by Month

# %%
sa.promotion_effect_by_month(train_store)

# %% [markdown]
# ### 8. Store promo effectiveness analysis

# %%
sa.store_promo_effectiveness(train_store)
# Out:
# 2024-09-20 20:00:34,860 - INFO - Plotting the effectiveness of promotion on based on store types...

# %% [markdown]
# ### 9. Store Type Sales Performance

# %%
sa.plot_store_type_performance(train_store)
# Out:
# 2024-09-20 20:08:11,233 - INFO - Plotting store type performance over time...

# %% [markdown]
# #### 9.1 Effect of Promotion by Store Type

# %%
sa.promotion_effect_by_store_type(train_store)

# %% [markdown]
# #### 9.2 Effect of Promotion by Store Type Through out the Months

# %%
sa.promotion_effect_by_store_type_month(train_store)

# %% [markdown]
# ### 10. Customer behavior during store opening times

# %%
sa.store_opening_closing_behavior(train_store)
# Out:
# 2024-09-20 20:09:52,748 - INFO - Plotting the behaviour of customers on opening times...
# 2024-09-20 20:09:52,862 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-09-20 20:09:52,879 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.

# %% [markdown]
# ### 11. Assortment type impact on sales

# %%
sa.assortment_sales(train_store)
# Out:
# 2024-09-20 20:11:02,628 - INFO - Plotting the Impact of Assortment on Sales...

# %% [markdown]
# ### 12. Competitor distance impact on sales

# %%
sa.competitor_distance_sales(train_store)
# Out:
# 2024-09-20 20:13:17,651 - INFO - Plotting the Impact of Competitor Distance on Sales...

# %% [markdown]
# ### 13. Competitor opening impact on sales

# %%
sa.competitor_opening_impact(train_store)
# Out:
# 2024-09-20 20:37:00,396 - INFO - Plotting the Impact of Competitor Opening on Sales...
