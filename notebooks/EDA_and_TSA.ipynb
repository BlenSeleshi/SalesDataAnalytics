# %% [markdown]
# ### Importing the Necessary Packages

# %%
import pandas as pd
import sys, os
import warnings
warnings.filterwarnings('ignore')

# %%
sys.path.append(os.path.abspath('../scripts'))

# %%
import EDA_and_TSA as eda

# %% [markdown]
# ### 1. Load Data

# %%
df = eda.load_data(r'C:\Users\Blen\OneDrive\Desktop\10Academy\SalesDataAnalytics\Data\train_store.csv')
# Out:
# INFO:root:Data loaded successfully.

# %% [markdown]
# ### 2. Rolling Mean and STD

# %%
# Plot rolling statistics with a window of 12 months (1 year)
eda.plot_rolling_statistics(df, window=12)

# %% [markdown]
# ### 3. 3. Decomposed Time Series

# %%
# Decompose the time series to show trend, seasonality, and residuals
eda.decompose_time_series(df, freq=365)

# %% [markdown]
# ### 4. ACF and PACF plot

# %%
# Plot the Autocorrelation Function (ACF) and Partial Autocorrelation Function (PACF)
eda.plot_acf_pacf(df, lags=30)

# %% [markdown]
# ### 5. Sales Distribution by Store and Year

# %%
# Visualize sales distribution by year and store type
eda.sales_distribution_by_store_year(df)
# Out:
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.

# %% [markdown]
# ### 6. Detect Outliers using IQR

# %%
# Detect and plot sales outliers using the Interquartile Range (IQR) method
outliers = eda.detect_outliers_iqr(df)
outliers.head()  # View detected outliers
# Out:
# INFO:root:Number of outliers detected: 26694
#      Store  DayOfWeek       Date  Sales  Customers  Open  Promo StateHoliday  \
# 6        7          4 2015-07-31  15344       1414     1      1            0
# 23      24          4 2015-07-31  14190       1082     1      1            0
# 24      25          4 2015-07-31  14180       1586     1      1            0
# 83      84          4 2015-07-31  14949       1439     1      1            0
# 107    108          4 2015-07-31  14927        992     1      1            0
#
#      SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 6                1         a          c              24000.0
# 23               1         a          c               4590.0
# 24               1         c          a                430.0
# 83               1         a          c              11810.0
# 107              0         d          c               2190.0
#
#      CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# ...

# %% [markdown]
# ### 7. Sales Growth Rate Over Time

# %%
# Calculate and plot sales growth rate over time
df_growth = eda.calculate_sales_growth(df)
df_growth.head()  # Check sales growth column
# Out:
#    Store  DayOfWeek       Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          4 2015-07-31   5263        555     1      1            0
# 1      2          4 2015-07-31   6064        625     1      1            0
# 2      3          4 2015-07-31   8314        821     1      1            0
# 3      4          4 2015-07-31  13995       1498     1      1            0
# 4      5          4 2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday StoreType  ... CompetitionDistance  \
# 0              1         c  ...              1270.0
# 1              1         a  ...               570.0
# 2              1         a  ...             14130.0
# 3              1         c  ...               620.0
# 4              1         a  ...             29910.0
#
#    CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                        9.0                    2008.0       0
# 1                       11.0                    2007.0       1
# ...

# %% [markdown]
# ### 8. Promo Effectiveness by Day of Week

# %%
# Analyze the effectiveness of promotions by day of the week
eda.promo_effectiveness_by_weekday(df)

# %% [markdown]
# ### 9. Count of State Holidays

# %%
# Plot the count of state holidays (0 means no holiday, other values mean there was a holiday)
eda.count_state_holidays(df)

# %% [markdown]
# ### 10. Count of School Holidays

# %%
# Plot the count of school holidays (1 means there was a school holiday, 0 means there was no school holiday)
eda.count_school_holidays(df)
# Out:
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.

# %% [markdown]
# ### 11.  Count of Store Types

# %%
# Visualize the count of different store types in the dataset
eda.count_store_types(df)

# %% [markdown]
# ### 11. Count of Assortment Types

# %%
# Visualize the count of different assortment types in the dataset
eda.count_assortment_types(df)

# %% [markdown]
# ### 14. Top 10 Features Correlated with Sales

# %%
# Plot the top 10 features that are most correlated with sales
eda.plot_top_correlations(df)
